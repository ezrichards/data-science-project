# %%
import soccerdata as sd
import matplotlib.pyplot as plt

# Get players
fbref = sd.FBref(leagues="ENG-Premier League", seasons=2022)
player_season_stats = fbref.read_player_season_stats(stat_type="standard")
player_season_stats.head()

list(player_season_stats)

# converting to integers
player_season_stats[('Performance', 'Gls')] = player_season_stats[('Performance', 'Gls')].astype(int)

# Filter players with goals above 10
filtered_players = player_season_stats[player_season_stats[('Performance', 'Gls')] > 10]

# Sort players by goals in descending order
sorted_players = filtered_players.sort_values(by=('Performance', 'Gls'), ascending=False)

player_names = sorted_players.index.get_level_values('player')
goals = sorted_players[('Performance', 'Gls')]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(player_names, goals)
plt.xlabel('Player')
plt.ylabel('Goals')
plt.title('Players with Goals > 10 in the 22-23 season')
plt.xticks(rotation=90)
plt.show()
# Out:
# [06/19/23 20:12:26] INFO     Saving cached data to /Users/ethanrichards/soccerdata/data/FBref         ]8;id=782580;file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=482134;file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/soccerdata/_common.py#89\89]8;;\
